# %% [markdown]
# # Selecting features
# When selecting the right features, there are some rules of thumb one can take into account. For example if one wants to segment objects very precisely, small radius / sigma values should be used. If a rough outline is enough, or if single individual pixels on borders of objects should be eliminated, it makes sense to use larger radius and sigma values. However, this topic can also be approached using statistics.

# %%
from skimage.io import imread, imsave
import pyclesperanto_prototype as cle
import numpy as np
import apoc
import matplotlib.pyplot as plt
import pandas as pd

# %%
image = imread('../../data/blobs.tif')

manual_annotation = imread('../../data/blobs_annotations.tif')

fig, axs = plt.subplots(1,2)

cle.imshow(image, plot=axs[0])
cle.imshow(manual_annotation, labels=True, plot=axs[1])

# %% [markdown]
# ## Training - with too many features
# We now train a object segmenter and provide many features. We also need to provide parameters to configure deep decision trees and many trees. This is necessary so that the next steps, deriving statistics, has enough statistical power.
# Afterwards, we take a look at the result for a quick sanity check.

# %%
# define features
features = apoc.PredefinedFeatureSet.small_dog_log.value + " " + \
           apoc.PredefinedFeatureSet.medium_dog_log.value + " " + \
           apoc.PredefinedFeatureSet.large_dog_log.value

# this is where the model will be saved
cl_filename = '../../data/blobs_object_segmenter2.cl'

apoc.erase_classifier(cl_filename)
classifier = apoc.ObjectSegmenter(opencl_filename=cl_filename, 
                           positive_class_identifier=2, 
                           max_depth=5,
                           num_ensembles=1000)
classifier.train(features, manual_annotation, image)

segmentation_result = classifier.predict(features=features, image=image)
cle.imshow(segmentation_result, labels=True)

# %% [markdown]
# ## Classifier statistics
# After training, we can print out some statistics from the classifier. It gives us a table of used features and how important the features were for making the pixel classification decision.

# %%
shares, counts = classifier.statistics()

def colorize(styler):
    styler.background_gradient(axis=None, cmap="rainbow")
    return styler

df = pd.DataFrame(shares).T
df.style.pipe(colorize)
# Out:
# <style type="text/css">
# #T_02b9d_row0_col0 {
#   background-color: #96fca7;
#   color: #000000;
# }
# #T_02b9d_row0_col1 {
#   background-color: #2489f5;
#   color: #f1f1f1;
# }
# #T_02b9d_row0_col2 {
#   background-color: #2c7ef7;
#   color: #f1f1f1;
# }
# #T_02b9d_row0_col3 {
#   background-color: #3670f8;
#   color: #f1f1f1;
# }
# #T_02b9d_row0_col4, #T_02b9d_row7_col1 {
#   background-color: #04b0ed;
#   color: #f1f1f1;
# }
# #T_02b9d_row1_col0 {
#   background-color: #ff5029;
#   color: #f1f1f1;
# }
# #T_02b9d_row1_col1 {
#   background-color: #3ae8d6;
#   color: #000000;
# }
# #T_02b9d_row1_col2 {
#   background-color: #14cae5;
#   color: #000000;
# }
# #T_02b9d_row1_col3, #T_02b9d_row3_col1 {
#   background-color: #54f6cb;
#   color: #000000;
# }
# #T_02b9d_row1_col4 {
#   background-color: #10a2f0;
#   color: #f1f1f1;
# }
# #T_02b9d_row2_col0, #T_02b9d_row3_col0 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_02b9d_row2_col1, #T_02b9d_row9_col2 {
#   background-color: #5af8c8;
#   color: #000000;
# }
# #T_02b9d_row2_col2, #T_02b9d_row4_col0 {
#   background-color: #40ecd4;
#   color: #000000;
# }
# #T_02b9d_row2_col3 {
#   background-color: #17cbe4;
#   color: #000000;
# }
# #T_02b9d_row2_col4 {
#   background-color: #2fe0db;
#   color: #000000;
# }
# #T_02b9d_row3_col2 {
#   background-color: #34e4d9;
#   color: #000000;
# }
# #T_02b9d_row3_col3, #T_02b9d_row7_col4 {
#   background-color: #22d6e0;
#   color: #000000;
# }
# #T_02b9d_row3_col4 {
#   background-color: #48f1d0;
#   color: #000000;
# }
# #T_02b9d_row4_col1 {
#   background-color: #02b7eb;
#   color: #f1f1f1;
# }
# #T_02b9d_row4_col2, #T_02b9d_row6_col3 {
#   background-color: #6efebe;
#   color: #000000;
# }
# #T_02b9d_row4_col3 {
#   background-color: #42edd3;
#   color: #000000;
# }
# #T_02b9d_row4_col4, #T_02b9d_row8_col4 {
#   background-color: #86ffb0;
#   color: #000000;
# }
# #T_02b9d_row5_col0 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_02b9d_row5_col1 {
#   background-color: #f0c46c;
#   color: #000000;
# }
# #T_02b9d_row5_col2 {
#   background-color: #62fbc4;
#   color: #000000;
# }
# #T_02b9d_row5_col3 {
#   background-color: #72febb;
#   color: #000000;
# }
# #T_02b9d_row5_col4 {
#   background-color: #6dfdbf;
#   color: #000000;
# }
# #T_02b9d_row6_col0 {
#   background-color: #ff8646;
#   color: #f1f1f1;
# }
# #T_02b9d_row6_col1 {
#   background-color: #ffac5c;
#   color: #000000;
# }
# #T_02b9d_row6_col2 {
#   background-color: #74feba;
#   color: #000000;
# }
# #T_02b9d_row6_col4 {
#   background-color: #7affb7;
#   color: #000000;
# }
# #T_02b9d_row7_col0 {
#   background-color: #780dff;
#   color: #f1f1f1;
# }
# #T_02b9d_row7_col2 {
#   background-color: #64fbc3;
#   color: #000000;
# }
# #T_02b9d_row7_col3, #T_02b9d_row8_col3 {
#   background-color: #80ffb4;
#   color: #000000;
# }
# #T_02b9d_row8_col0 {
#   background-color: #4062fa;
#   color: #f1f1f1;
# }
# #T_02b9d_row8_col1 {
#   background-color: #10c6e6;
#   color: #000000;
# }
# #T_02b9d_row8_col2 {
#   background-color: #76ffb9;
#   color: #000000;
# }
# #T_02b9d_row9_col0 {
#   background-color: #3176f8;
#   color: #f1f1f1;
# }
# #T_02b9d_row9_col1 {
#   background-color: #0fc4e7;
#   color: #000000;
# }
# #T_02b9d_row9_col3, #T_02b9d_row9_col4 {
#   background-color: #60fac5;
#   color: #000000;
# }
# </style>
# <table id="T_02b9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02b9d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_02b9d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_02b9d_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_02b9d_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_02b9d_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02b9d_level0_row0" class="row_heading level0 row0" >original</th>
#       <td id="T_02b9d_row0_col0" class="data row0 col0" >0.138000</td>
#       <td id="T_02b9d_row0_col1" class="data row0 col1" >0.046423</td>
#       <td id="T_02b9d_row0_col2" class="data row0 col2" >0.042312</td>
#       <td id="T_02b9d_row0_col3" class="data row0 col3" >0.037281</td>
#       <td id="T_02b9d_row0_col4" class="data row0 col4" >0.062112</td>
#     </tr>
#     <tr>
#       <th id="T_02b9d_level0_row1" class="row_heading level0 row1" >gaussian_blur=1</th>
#       <td id="T_02b9d_row1_col0" class="data row1 col0" >0.228000</td>
#       <td id="T_02b9d_row1_col1" class="data row1 col1" >0.092846</td>
#       <td id="T_02b9d_row1_col2" class="data row1 col2" >0.074303</td>
#       <td id="T_02b9d_row1_col3" class="data row1 col3" >0.105263</td>
#       <td id="T_02b9d_row1_col4" class="data row1 col4" >0.055901</td>
#     </tr>
#     <tr>
#       <th id="T_02b9d_level0_row2" class="row_heading level0 row2" >difference_of_gaussian=1</th>
#       <td id="T_02b9d_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_02b9d_row2_col1" class="data row2 col1" >0.108828</td>
#       <td id="T_02b9d_row2_col2" class="data row2 col2" >0.095975</td>
#       <td id="T_02b9d_row2_col3" class="data row2 col3" >0.074561</td>
#       <td id="T_02b9d_row2_col4" class="data row2 col4" >0.086957</td>
#     </tr>
#     <tr>
#       <th id="T_02b9d_level0_row3" class="row_heading level0 row3" >laplace_box_of_gaussian_blur=1</th>
#       <td id="T_02b9d_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_02b9d_row3_col1" class="data row3 col1" >0.105784</td>
#       <td id="T_02b9d_row3_col2" class="data row3 col2" >0.089783</td>
#       <td id="T_02b9d_row3_col3" class="data row3 col3" >0.081140</td>
#       <td id="T_02b9d_row3_col4" class="data row3 col4" >0.099379</td>
#     </tr>
#     <tr>
#       <th id="T_02b9d_level0_row4" class="row_heading level0 row4" >gaussian_blur=5</th>
#       <td id="T_02b9d_row4_col0" class="data row4 col0" >0.096000</td>
#       <td id="T_02b9d_row4_col1" class="data row4 col1" >0.064688</td>
#       <td id="T_02b9d_row4_col2" class="data row4 col2" >0.118679</td>
#       <td id="T_02b9d_row4_col3" class="data row4 col3" >0.096491</td>
#       <td id="T_02b9d_row4_col4" class="data row4 col4" >0.130435</td>
#     </tr>
#     <tr>
#       <th id="T_02b9d_level0_row5" class="row_heading level0 row5" >difference_of_gaussian=5</th>
#       <td id="T_02b9d_row5_col0" class="data row5 col0" >0.254000</td>
#       <td id="T_02b9d_row5_col1" class="data row5 col1" >0.182648</td>
#       <td id="T_02b9d_row5_col2" class="data row5 col2" >0.112487</td>
#       <td id="T_02b9d_row5_col3" class="data row5 col3" >0.120614</td>
#       <td id="T_02b9d_row5_col4" class="data row5 col4" >0.118012</td>
#     </tr>
#     <tr>
#       <th id="T_02b9d_level0_row6" class="row_heading level0 row6" >laplace_box_of_gaussian_blur=5</th>
#       <td id="T_02b9d_row6_col0" class="data row6 col0" >0.209000</td>
#       <td id="T_02b9d_row6_col1" class="data row6 col1" >0.194064</td>
#       <td id="T_02b9d_row6_col2" class="data row6 col2" >0.121775</td>
#       <td id="T_02b9d_row6_col3" class="data row6 col3" >0.118421</td>
#       <td id="T_02b9d_row6_col4" class="data row6 col4" >0.124224</td>
#     </tr>
#     <tr>
#       <th id="T_02b9d_level0_row7" class="row_heading level0 row7" >gaussian_blur=25</th>
#       <td id="T_02b9d_row7_col0" class="data row7 col0" >0.004000</td>
#       <td id="T_02b9d_row7_col1" class="data row7 col1" >0.061644</td>
#       <td id="T_02b9d_row7_col2" class="data row7 col2" >0.113519</td>
#       <td id="T_02b9d_row7_col3" class="data row7 col3" >0.127193</td>
#       <td id="T_02b9d_row7_col4" class="data row7 col4" >0.080745</td>
#     </tr>
#     <tr>
#       <th id="T_02b9d_level0_row8" class="row_heading level0 row8" >difference_of_gaussian=25</th>
#       <td id="T_02b9d_row8_col0" class="data row8 col0" >0.032000</td>
#       <td id="T_02b9d_row8_col1" class="data row8 col1" >0.072298</td>
#       <td id="T_02b9d_row8_col2" class="data row8 col2" >0.122807</td>
#       <td id="T_02b9d_row8_col3" class="data row8 col3" >0.127193</td>
#       <td id="T_02b9d_row8_col4" class="data row8 col4" >0.130435</td>
#     </tr>
#     <tr>
#       <th id="T_02b9d_level0_row9" class="row_heading level0 row9" >laplace_box_of_gaussian_blur=25</th>
#       <td id="T_02b9d_row9_col0" class="data row9 col0" >0.039000</td>
#       <td id="T_02b9d_row9_col1" class="data row9 col1" >0.070776</td>

# %% [markdown]
# In this visualization you can see that the features `gaussian_blur=1`, `difference_of_gaussian=5` and `laplace_box_of_gaussian_blur=5` make about 65% of the decision. On the first level (level `0`). If these three features are crucial, we can train another classifier that only takes these features into account. Furthermore, we see that the share the features are used on the higher three depth levels is more uniformly distributed. These levels may not make a big difference when classifying pixels. The next classifier we train, we can train with lower `max_depth`.

# %%
# define features
features = "gaussian_blur=1 difference_of_gaussian=5 laplace_box_of_gaussian_blur=5"

# this is where the model will be saved
cl_filename = '../../data/blobs_object_segmenter3.cl'

apoc.erase_classifier(cl_filename)
classifier = apoc.ObjectSegmenter(opencl_filename=cl_filename, 
                           positive_class_identifier=2, 
                           max_depth=3,
                           num_ensembles=1000)
classifier.train(features, manual_annotation, image)

segmentation_result = classifier.predict(features=features, image=image)
cle.imshow(segmentation_result, labels=True)

# %% [markdown]
# The new classifier still produces a very similar result. It takes less features into account, which makes it faster, but potentially also less robust against differences between images and imaging conditions. We just take another look at the classifier statistics:

# %%
shares, counts = classifier.statistics()
df = pd.DataFrame(shares).T
df.style.pipe(colorize)
# Out:
# <style type="text/css">
# #T_9adf3_row0_col0 {
#   background-color: #56f7ca;
#   color: #000000;
# }
# #T_9adf3_row0_col1 {
#   background-color: #ff793e;
#   color: #f1f1f1;
# }
# #T_9adf3_row0_col2 {
#   background-color: #f9bb66;
#   color: #000000;
# }
# #T_9adf3_row1_col0 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_9adf3_row1_col1 {
#   background-color: #48f1d0;
#   color: #000000;
# }
# #T_9adf3_row1_col2 {
#   background-color: #9efaa2;
#   color: #000000;
# }
# #T_9adf3_row2_col0 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_9adf3_row2_col1 {
#   background-color: #218cf4;
#   color: #f1f1f1;
# }
# #T_9adf3_row2_col2 {
#   background-color: #425ffa;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9adf3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9adf3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9adf3_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_9adf3_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9adf3_level0_row0" class="row_heading level0 row0" >gaussian_blur=1</th>
#       <td id="T_9adf3_row0_col0" class="data row0 col0" >0.331000</td>
#       <td id="T_9adf3_row0_col1" class="data row0 col1" >0.349194</td>
#       <td id="T_9adf3_row0_col2" class="data row0 col2" >0.344620</td>
#     </tr>
#     <tr>
#       <th id="T_9adf3_level0_row1" class="row_heading level0 row1" >difference_of_gaussian=5</th>
#       <td id="T_9adf3_row1_col0" class="data row1 col0" >0.356000</td>
#       <td id="T_9adf3_row1_col1" class="data row1 col1" >0.329839</td>
#       <td id="T_9adf3_row1_col2" class="data row1 col2" >0.337096</td>
#     </tr>
#     <tr>
#       <th id="T_9adf3_level0_row2" class="row_heading level0 row2" >laplace_box_of_gaussian_blur=5</th>
#       <td id="T_9adf3_row2_col0" class="data row2 col0" >0.313000</td>
#       <td id="T_9adf3_row2_col1" class="data row2 col1" >0.320968</td>
#       <td id="T_9adf3_row2_col2" class="data row2 col2" >0.318284</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# For demonstration purposes, we will now train another classifier with very similar features.

# %%
# define features
features = "gaussian_blur=1 difference_of_gaussian=2 difference_of_gaussian=3 difference_of_gaussian=4 difference_of_gaussian=5 difference_of_gaussian=6 laplace_box_of_gaussian_blur=5"

# this is where the model will be saved
cl_filename = '../../data/blobs_object_segmenter3.cl'

apoc.erase_classifier(cl_filename)
classifier = apoc.ObjectSegmenter(opencl_filename=cl_filename, 
                           positive_class_identifier=2, 
                           max_depth=3,
                           num_ensembles=1000)
classifier.train(features, manual_annotation, image)

segmentation_result = classifier.predict(features=features, image=image)
cle.imshow(segmentation_result, labels=True)

# %% [markdown]
# Again, the segmentation result looks very similar, but the classifier statistic is different.

# %%
shares, counts = classifier.statistics()
df = pd.DataFrame(shares).T
df.style.pipe(colorize)
# Out:
# <style type="text/css">
# #T_404f5_row0_col0 {
#   background-color: #ff763d;
#   color: #f1f1f1;
# }
# #T_404f5_row0_col1 {
#   background-color: #4af2cf;
#   color: #000000;
# }
# #T_404f5_row0_col2, #T_404f5_row3_col1 {
#   background-color: #e0d377;
#   color: #000000;
# }
# #T_404f5_row1_col0 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_404f5_row1_col1 {
#   background-color: #86ffb0;
#   color: #000000;
# }
# #T_404f5_row1_col2 {
#   background-color: #c0eb8d;
#   color: #000000;
# }
# #T_404f5_row2_col0 {
#   background-color: #0ea5ef;
#   color: #f1f1f1;
# }
# #T_404f5_row2_col1 {
#   background-color: #0dc2e8;
#   color: #000000;
# }
# #T_404f5_row2_col2 {
#   background-color: #8efeac;
#   color: #000000;
# }
# #T_404f5_row3_col0 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_404f5_row3_col2 {
#   background-color: #52f5cb;
#   color: #000000;
# }
# #T_404f5_row4_col0 {
#   background-color: #ffb05f;
#   color: #000000;
# }
# #T_404f5_row4_col1 {
#   background-color: #ff2c16;
#   color: #f1f1f1;
# }
# #T_404f5_row4_col2 {
#   background-color: #90feab;
#   color: #000000;
# }
# #T_404f5_row5_col0 {
#   background-color: #a2f9a0;
#   color: #000000;
# }
# #T_404f5_row5_col1 {
#   background-color: #84ffb2;
#   color: #000000;
# }
# #T_404f5_row5_col2 {
#   background-color: #ff8444;
#   color: #f1f1f1;
# }
# #T_404f5_row6_col0 {
#   background-color: #ff793e;
#   color: #f1f1f1;
# }
# #T_404f5_row6_col1 {
#   background-color: #ff4724;
#   color: #f1f1f1;
# }
# #T_404f5_row6_col2 {
#   background-color: #bced8f;
#   color: #000000;
# }
# </style>
# <table id="T_404f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_404f5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_404f5_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_404f5_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_404f5_level0_row0" class="row_heading level0 row0" >gaussian_blur=1</th>
#       <td id="T_404f5_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_404f5_row0_col1" class="data row0 col1" >0.093750</td>
#       <td id="T_404f5_row0_col2" class="data row0 col2" >0.162829</td>
#     </tr>
#     <tr>
#       <th id="T_404f5_level0_row1" class="row_heading level0 row1" >difference_of_gaussian=2</th>
#       <td id="T_404f5_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_404f5_row1_col1" class="data row1 col1" >0.120888</td>
#       <td id="T_404f5_row1_col2" class="data row1 col2" >0.148026</td>
#     </tr>
#     <tr>
#       <th id="T_404f5_level0_row2" class="row_heading level0 row2" >difference_of_gaussian=3</th>
#       <td id="T_404f5_row2_col0" class="data row2 col0" >0.053000</td>
#       <td id="T_404f5_row2_col1" class="data row2 col1" >0.064967</td>
#       <td id="T_404f5_row2_col2" class="data row2 col2" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_404f5_level0_row3" class="row_heading level0 row3" >difference_of_gaussian=4</th>
#       <td id="T_404f5_row3_col0" class="data row3 col0" >0.236000</td>
#       <td id="T_404f5_row3_col1" class="data row3 col1" >0.162829</td>
#       <td id="T_404f5_row3_col2" class="data row3 col2" >0.097039</td>
#     </tr>
#     <tr>
#       <th id="T_404f5_level0_row4" class="row_heading level0 row4" >difference_of_gaussian=5</th>
#       <td id="T_404f5_row4_col0" class="data row4 col0" >0.178000</td>
#       <td id="T_404f5_row4_col1" class="data row4 col1" >0.222862</td>
#       <td id="T_404f5_row4_col2" class="data row4 col2" >0.125822</td>
#     </tr>
#     <tr>
#       <th id="T_404f5_level0_row5" class="row_heading level0 row5" >difference_of_gaussian=6</th>
#       <td id="T_404f5_row5_col0" class="data row5 col0" >0.134000</td>
#       <td id="T_404f5_row5_col1" class="data row5 col1" >0.120066</td>
#       <td id="T_404f5_row5_col2" class="data row5 col2" >0.194901</td>
#     </tr>
#     <tr>
#       <th id="T_404f5_level0_row6" class="row_heading level0 row6" >laplace_box_of_gaussian_blur=5</th>
#       <td id="T_404f5_row6_col0" class="data row6 col0" >0.199000</td>
#       <td id="T_404f5_row6_col1" class="data row6 col1" >0.214638</td>
#       <td id="T_404f5_row6_col2" class="data row6 col2" >0.146382</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# In that way one can also fine-tune the radius and sigma parameters one needs to use for the specified features.
#
# The hints given here in this section are no solid rules for selecting the right features. The provided tools may help though for looking a bit behind the features and for measuring the influence provided feature lists and parameters have.
