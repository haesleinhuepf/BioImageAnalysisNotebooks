# %% [markdown]
# # Feature correlation
#
# When inspecting feature extraction results, it is often important to take releationships between features into account. Therefore, a feature correlation matrix is a useful tool. Visualizing it in color is recommended.

# %%
from napari_simpleitk_image_processing import label_statistics
import numpy as np
import seaborn
import pyclesperanto_prototype as cle
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data
# We first load the image data that will be used for feature extraction.

# %%
# Load data
image = cle.imread("../../data/Lund-25MB.tif")

# Segment nuclei
background_subtracted = cle.top_hat_box(image, radius_x=5, radius_y=5)
labels = cle.voronoi_otsu_labeling(background_subtracted, spot_sigma=1)

# Feature extraction
nuclei_statistics = label_statistics(image, labels, 
                                     intensity=True, 
                                     size=True, 
                                     shape=True, 
                                     perimeter=True,
                                     moments=True)

# Feature selection
selected_table = nuclei_statistics[
    [
       # likely unrelated features
       'label', 
        
       # intensity releated features
       'maximum', 'mean', 'minimum', 'variance',
        
       # shape related features 
       'elongation', 'feret_diameter', 'flatness', 'roundness',

       # size related features
       'equivalent_spherical_radius', 'number_of_pixels', 'perimeter'
    ]
]
selected_table
# Out:
# C:\Users\haase\miniconda3\envs\bio311\Lib\site-packages\pyclesperanto_prototype\_tier9\_imread.py:5: UserWarning: cle.imread is deprecated, use skimage.io.imread instead.
#   warnings.warn("cle.imread is deprecated, use skimage.io.imread instead.")
#       label  maximum        mean  minimum    variance  elongation  \
# 0         1    143.0  117.489451     93.0   90.056032    1.228690
# 1         2    113.0   83.052219     65.0   94.086271    1.325096
# 2         3    130.0  108.930403     92.0   57.109109    1.565911
# 3         4    129.0   94.576991     70.0  130.716136    1.227027
# 4         5    149.0  119.454545     89.0  144.431321    1.429829
# ...     ...      ...         ...      ...         ...         ...
# 1195   1196     60.0   42.118257     29.0   50.270809    1.107046
# 1196   1197     83.0   47.673267     29.0  159.330772    1.046951
# 1197   1198     53.0   41.502890     30.0   28.123180    1.042599
# 1198   1199     72.0   45.091570     29.0  106.316202    1.114285
# 1199   1200     66.0   44.232682     29.0   67.484909    1.203239
#
#       feret_diameter  flatness  roundness  equivalent_spherical_radius  \
# 0           8.774964  1.153618   0.965657                     3.839016
# 1          13.152946  1.215572   0.818905                     4.505089
# 2          12.884099  1.434476   0.807173                     4.024309
# 3          14.352700  1.397276   0.833006                     5.128456
# 4          10.723805  1.269121   0.871680                     4.034113
# ...              ...       ...        ...                          ...
# 1195       11.090537  1.307962   0.976306                     4.863917
# 1196       12.409674  1.236147   0.962602                     5.526416
# 1197        9.643651  1.330995   0.965376                     4.355077
# 1198       12.961481  1.269182   0.962037                     5.476460
# 1199       12.206556  1.381601   0.961668                     5.122397
#
#       number_of_pixels   perimeter
# 0                  237  191.790349
# 1                  383  311.446414
# 2                  273  252.130963
# 3                  565  396.766310
# 4                  275  234.611278
# ...                ...         ...
# 1195               482  304.506355
# 1196               707  398.703613
# 1197               346  246.890816
# 1198               688  391.758021
# 1199               563  342.871234
#
# [1200 rows x 12 columns]

# %% [markdown]
# ### Correlation matrix
# We examine the correlation between the selected features to understand their relationships.

# %%
df = selected_table.corr()

def colorize(styler):
    styler.background_gradient(axis=None, cmap="coolwarm")
    return styler
df.style.pipe(colorize)
# Out:
# <style type="text/css">
# #T_36ff2_row0_col0, #T_36ff2_row1_col1, #T_36ff2_row2_col2, #T_36ff2_row3_col3, #T_36ff2_row4_col4, #T_36ff2_row5_col5, #T_36ff2_row6_col6, #T_36ff2_row7_col7, #T_36ff2_row8_col8, #T_36ff2_row9_col9, #T_36ff2_row10_col10, #T_36ff2_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_36ff2_row0_col1, #T_36ff2_row1_col0, #T_36ff2_row3_col8, #T_36ff2_row3_col10, #T_36ff2_row8_col3, #T_36ff2_row10_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_36ff2_row0_col2, #T_36ff2_row2_col0, #T_36ff2_row2_col8, #T_36ff2_row8_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_36ff2_row0_col3, #T_36ff2_row3_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_36ff2_row0_col4, #T_36ff2_row4_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_36ff2_row0_col5, #T_36ff2_row5_col0 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_36ff2_row0_col6, #T_36ff2_row6_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_36ff2_row0_col7, #T_36ff2_row7_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_36ff2_row0_col8, #T_36ff2_row8_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_36ff2_row0_col9, #T_36ff2_row9_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_36ff2_row0_col10, #T_36ff2_row10_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_36ff2_row0_col11, #T_36ff2_row11_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_36ff2_row1_col2, #T_36ff2_row2_col1 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_36ff2_row1_col3, #T_36ff2_row3_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_36ff2_row1_col4, #T_36ff2_row4_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_36ff2_row1_col5, #T_36ff2_row5_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_36ff2_row1_col6, #T_36ff2_row3_col7, #T_36ff2_row6_col1, #T_36ff2_row7_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_36ff2_row1_col7, #T_36ff2_row7_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_36ff2_row1_col8, #T_36ff2_row8_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_36ff2_row1_col9, #T_36ff2_row9_col1 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_36ff2_row1_col10, #T_36ff2_row10_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_36ff2_row1_col11, #T_36ff2_row4_col8, #T_36ff2_row8_col4, #T_36ff2_row11_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_36ff2_row2_col3, #T_36ff2_row3_col2 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_36ff2_row2_col4, #T_36ff2_row4_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_36ff2_row2_col5, #T_36ff2_row5_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_36ff2_row2_col6, #T_36ff2_row6_col2 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_36ff2_row2_col7, #T_36ff2_row7_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_36ff2_row2_col9, #T_36ff2_row9_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_36ff2_row2_col10, #T_36ff2_row10_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_36ff2_row2_col11, #T_36ff2_row11_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_36ff2_row3_col4, #T_36ff2_row4_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_36ff2_row3_col5, #T_36ff2_row5_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_36ff2_row3_col6, #T_36ff2_row6_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_36ff2_row3_col9, #T_36ff2_row9_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_36ff2_row3_col11, #T_36ff2_row11_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_36ff2_row4_col5, #T_36ff2_row5_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_36ff2_row4_col6, #T_36ff2_row6_col4 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_36ff2_row4_col7, #T_36ff2_row5_col11, #T_36ff2_row7_col4, #T_36ff2_row7_col11, #T_36ff2_row11_col5, #T_36ff2_row11_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_36ff2_row4_col9, #T_36ff2_row4_col10, #T_36ff2_row9_col4, #T_36ff2_row10_col4 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_36ff2_row4_col11, #T_36ff2_row11_col4 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_36ff2_row5_col6, #T_36ff2_row6_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_36ff2_row5_col7, #T_36ff2_row7_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_36ff2_row5_col8, #T_36ff2_row8_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_36ff2_row5_col9, #T_36ff2_row9_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_36ff2_row5_col10, #T_36ff2_row10_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_36ff2_row6_col7, #T_36ff2_row7_col6 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_36ff2_row6_col8, #T_36ff2_row8_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_36ff2_row6_col9, #T_36ff2_row9_col6 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_36ff2_row6_col10, #T_36ff2_row10_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_36ff2_row6_col11, #T_36ff2_row11_col6 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_36ff2_row7_col8, #T_36ff2_row8_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_36ff2_row7_col9, #T_36ff2_row9_col7 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_36ff2_row7_col10, #T_36ff2_row10_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_36ff2_row8_col9, #T_36ff2_row9_col8 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_36ff2_row8_col10, #T_36ff2_row10_col8 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_36ff2_row8_col11, #T_36ff2_row11_col8 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_36ff2_row9_col10, #T_36ff2_row10_col9 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_36ff2_row9_col11, #T_36ff2_row11_col9 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_36ff2_row10_col11, #T_36ff2_row11_col10 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_36ff2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36ff2_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_36ff2_level0_col1" class="col_heading level0 col1" >maximum</th>
#       <th id="T_36ff2_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_36ff2_level0_col3" class="col_heading level0 col3" >minimum</th>
#       <th id="T_36ff2_level0_col4" class="col_heading level0 col4" >variance</th>
#       <th id="T_36ff2_level0_col5" class="col_heading level0 col5" >elongation</th>
#       <th id="T_36ff2_level0_col6" class="col_heading level0 col6" >feret_diameter</th>
#       <th id="T_36ff2_level0_col7" class="col_heading level0 col7" >flatness</th>
#       <th id="T_36ff2_level0_col8" class="col_heading level0 col8" >roundness</th>
#       <th id="T_36ff2_level0_col9" class="col_heading level0 col9" >equivalent_spherical_radius</th>
#       <th id="T_36ff2_level0_col10" class="col_heading level0 col10" >number_of_pixels</th>
#       <th id="T_36ff2_level0_col11" class="col_heading level0 col11" >perimeter</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36ff2_level0_row0" class="row_heading level0 row0" >label</th>
#       <td id="T_36ff2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_36ff2_row0_col1" class="data row0 col1" >-0.605035</td>
#       <td id="T_36ff2_row0_col2" class="data row0 col2" >-0.651268</td>
#       <td id="T_36ff2_row0_col3" class="data row0 col3" >-0.581233</td>
#       <td id="T_36ff2_row0_col4" class="data row0 col4" >-0.134539</td>
#       <td id="T_36ff2_row0_col5" class="data row0 col5" >-0.014857</td>
#       <td id="T_36ff2_row0_col6" class="data row0 col6" >0.105859</td>
#       <td id="T_36ff2_row0_col7" class="data row0 col7" >-0.066384</td>
#       <td id="T_36ff2_row0_col8" class="data row0 col8" >0.381267</td>
#       <td id="T_36ff2_row0_col9" class="data row0 col9" >0.251968</td>
#       <td id="T_36ff2_row0_col10" class="data row0 col10" >0.246869</td>
#       <td id="T_36ff2_row0_col11" class="data row0 col11" >0.190365</td>
#     </tr
